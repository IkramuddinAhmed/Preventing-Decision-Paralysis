# %% [markdown]
# ## Integrated Public Alert and Warning System Data
#
# The Integrated Public Alert and Warning System (IPAWS) Archived Alerts V1 dataset from FEMA provides historical data on public alerts and warnings issued through the IPAWS system. This system is a national platform designed to disseminate emergency alerts to the public through various channels, including radio, television, cell phones, and the internet.
#
# Documents past alerts issued for emergencies like natural disasters, public safety incidents, and other critical events. This dataset aids in research, analysis, and improvement of emergency communication and response.
#
# It contains several important data points such as: Issuing agency or authority, Date and time of the alert issuance, Type of alert (e.g., AMBER Alert, Severe Weather, Evacuation Notice), Geographical coverage (e.g., counties, states, ZIP codes), Alert language and category, CAP (Common Alerting Protocol) elements, such as urgency, severity, and certainty. It also links to full alert messages or additional resources.
#
# This Data is available as a machine-readable dataset for public access, the formats include JSON and CSV for integration with analytical tools.

# %% [markdown]
# ### Data Usage
#
# Here, we will be extracting the data from its API and cleaning it for our usecase of **Decision Paralysis** for *Disaster Response and Emergency Management*.
#
# This is a huge dataset and for Proof of Concept purposes, we will be fetching a part of the actual dataset based on RAM and Memory constraints on a normal PC.

# %% [markdown]
# ### Data Extraction

# %%
# !pip install psutil
# Out:
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (5.9.5)

# %%
import requests
import time
import psutil

# Initializing parameters
url = "https://www.fema.gov/api/open/v1/IpawsArchivedAlerts"
top = 1000  # Number of records to fetch per request
skip = 0    # Starting point for records to skip
all_records = []

# Setting the timeout duration (20 minutes)
timeout_duration = 20 * 60  # 20 minutes in seconds
start_time = time.time()  # Record the start time

# Define a RAM usage limit in bytes (e.g., 70% of total RAM)
ram_limit = psutil.virtual_memory().total * 0.7

# Checking current RAM usage and returning True if usage exceeds the limit.
def check_ram_usage():
    used_ram = psutil.virtual_memory().used
    return used_ram > ram_limit

try:
    while True:
        # Check for timeout
        elapsed_time = time.time() - start_time
        if elapsed_time > timeout_duration:
            print("Timeout occurred. Stopping execution.")
            break

        # Check for RAM usage
        if check_ram_usage():
            print("RAM usage exceeded the limit. Stopping execution.")
            break

        # Constructing the API request URL with $skip and $top parameters
        request_url = f"{url}?$skip={skip}&$top={top}"
        response = requests.get(request_url)

        if response.status_code == 200:
            data = response.json()
            alerts = data.get('IpawsArchivedAlerts', [])
            if not alerts:
                # No more records to fetch
                break
            all_records.extend(alerts)

            # Increment skip by the number of records fetched
            skip += len(alerts)
        else:
            print(f"Error: {response.status_code}")
            break
except Exception as e:
    print(f"An error occurred: {e}")

print(f"Total records fetched: {len(all_records)}")
# Out:
# RAM usage exceeded the limit. Stopping execution.
# Total records fetched: 414000

# %% [markdown]
# ### Data Preprocessing

# %%
import pandas as pd
df = pd.DataFrame(all_records)
print(len(df))
# Out:
# 414000

# %% [markdown]
# Expanding the data nested within attributes

# %%
def extract_info(row):
    info = row.get('info')  # Get the 'info' column value
    if not info or not isinstance(info, list):  # Check if info is valid and a list
        return pd.Series()  # Return empty Series for invalid rows

    # Extract the first dictionary from the list
    info = info[0] if len(info) > 0 else {}

    result = {
        'web': info.get('web'),
        'event': info.get('event'),
        'onset': info.get('onset'),
        'expires': info.get('expires'),
        'urgency': info.get('urgency'),
        'category': ', '.join(info.get('category', [])),  # Join list to single string if needed
        'headline': info.get('headline'),
        'severity': info.get('severity'),
        'certainty': info.get('certainty'),
        'effective': info.get('effective'),
        'senderName': info.get('senderName'),
        'description': info.get('description'),
        'instruction': info.get('instruction'),
        'responseType': ', '.join(info.get('responseType', [])),
    }

    # Extract nested areas information
    area_info = info.get('areas', [{}])[0] if info.get('areas') else {}
    result['areaDesc'] = area_info.get('areaDesc')

    # Extract polygon coordinates if present
    polygon = area_info.get('polygon', {})
    result['polygon_type'] = polygon.get('type')
    result['polygon_coordinates'] = polygon.get('coordinates')

    # Extract eventCode information
    event_codes = info.get('eventCode', [])
    for i, event_code in enumerate(event_codes):
        result[f'eventCode_{i}_name'] = event_code.get('name')
        result[f'eventCode_{i}_value'] = event_code.get('value')

    # Extract parameters information
    parameters = info.get('parameters', [])
    for i, param in enumerate(parameters):
        result[f'param_{param.get("name")}'] = param.get('value')

    return pd.Series(result)

# Apply function to DataFrame
extracted_info = df.apply(extract_info, axis=1)

# %%
# Combine the extracted columns with the original DataFrame
df = pd.concat([df.drop(columns=['info', 'originalMessage', 'sender', 'source', 'scope', 'restriction', 'addresses', 'code', 'note', 'incidents', 'cogId', 'xmlns'], inplace=True), extracted_info], axis=1)

# %%
df
# Out:
#                                                  areaDesc category certainty  \
# 0                            Port Heiden to Cape Sarichef      Met  Observed
# 1                                           Kiska to Attu      Met    Likely
# 2       Carter, OK; Coal, OK; Garvin, OK; Johnston, OK...      Met  Observed
# 3       Green Bay south of line from  Cedar River to R...      Met    Likely
# 4       Coastal waters from Baffin Bay to Port Aransas...      Met    Likely
# ...                                                   ...      ...       ...
# 413995  Marion; Wahkiakum; Clackamas; Columbia; Washin...      Met    Likely
# 413996                                             Marion      Met  Possible
# 413997  Rich; Utah; Weber; Wasatch; Cache; Morgan; Jua...      Met    Likely
# 413998  Marquette to Munising MI; Huron Islands to Mar...      Met    Likely
# 413999  Chesapeake Bay from New Point Comfort to Littl...      Met    Likely
#
#                                               description  \
# 0       AAA\n\n.TONIGHT...SW wind 40 kt increasing to ...
# 1       AAA\n\n.TONIGHT...SW wind 20 kt becoming S 45 ...
# 2       The National Weather Service in Norman has iss...
# 3       Winds have subsided over the Bay of Green Bay ...
# 4       * WHAT...South winds 20 to 25 knots with gusts...
# ...                                                   ...
# 413995  THE NATIONAL WEATHER SERVICE IN PORTLAND HAS C...
# 413996  KSC115-252200-\n/O.CAN.KICT.SV.A.0520.000000T0...
# 413997  * AFFECTED AREA...THE WASATCH MOUNTAINS OF NOR...
# 413998  A SMALL CRAFT ADVISORY REMAINS IN EFFECT UNTIL...
# 413999  THE NATIONAL WEATHER SERVICE IN WAKEFIELD HAS ...
#
#                         effective                        event  \
# 0       2021-10-10T18:33:00-08:00                Storm Warning
# 1       2021-10-10T18:33:00-08:00                 Gale Warning
# 2       2021-10-10T20:59:00-05:00  Severe Thunderstorm Warning
# 3       2021-10-10T21:45:00-05:00         Small Craft Advisory
# 4       2021-10-10T21:56:00-05:00         Small Craft Advisory
# ...                           ...                          ...
# 413995  2016-12-17T14:37:34-08:00      Winter Weather Advisory
# 413996  2016-12-25T14:58:14-06:00    Severe Thunderstorm Watch
# 413997  2016-12-25T15:33:36-07:00         Winter Storm Warning
# 413998  2016-12-27T10:29:49-05:00         Small Craft Advisory
# 413999  2016-12-26T01:02:35-05:00         Small Craft Advisory
#
#        eventCode_0_name eventCode_0_value        eventCode_1_name  \
# 0                  SAME               NWS  NationalWeatherService
# 1                  SAME               NWS  NationalWeatherService
# 2                  SAME               SVR  NationalWeatherService
# 3                  SAME               NWS  NationalWeatherService
# 4                  SAME               NWS  NationalWeatherService
# ...                 ...               ...                     ...
# 413995             SAME               NWS  NationalWeatherService
# 413996             SAME               SVA                     NaN
# 413997             SAME               WSW                     NaN
# 413998             SAME               NWS  NationalWeatherService
# 413999             SAME               NWS  NationalWeatherService
#
#        eventCode_1_value  ... param_waterspoutDetection param_windGust  \
# 0                    SRW  ...                       NaN            NaN
# 1                    GLW  ...                       NaN            NaN
# 2                    SVW  ...                       NaN            NaN
# 3                    SCY  ...                       NaN            NaN
# 4                    SCY  ...                       NaN            NaN
# ...                  ...  ...                       ...            ...
# 413995               WWY  ...                       NaN            NaN
# 413996               NaN  ...                       NaN            NaN
# 413997               NaN  ...                       NaN            NaN
# 413998               SCY  ...                       NaN            NaN
# 413999               SCY  ...                       NaN            NaN
#
#        param_windThreat                                polygon_coordinates  \
# 0                   NaN                                               None
# 1                   NaN                                               None
# 2       RADAR INDICATED  [[[-96.43, 34.41], [-97.36, 34.19], [-97.24, 3...
# 3                   NaN                                               None
# 4                   NaN                                               None
# ...                 ...                                                ...
# 413995              NaN                                               None
# 413996              NaN                                               None
# 413997              NaN                                               None
# 413998              NaN                                               None
# 413999              NaN                                               None
#
#        polygon_type responseType             senderName  severity    urgency  \
# 0              None        Avoid       NWS Anchorage AK    Severe  Immediate
# 1              None        Avoid       NWS Anchorage AK  Moderate   Expected
# 2           Polygon      Shelter          NWS Norman OK    Severe  Immediate
# 3              None        Avoid       NWS Green Bay WI     Minor   Expected
# 4              None        Avoid  NWS Corpus Christi TX     Minor   Expected
# ...             ...          ...                    ...       ...        ...
# 413995         None      Execute        NWS Portland OR  Moderate   Expected
# 413996         None      Monitor         NWS Wichita KS    Severe     Future
# 413997         None      Prepare  NWS Salt Lake City UT    Severe   Expected
# 413998         None        Avoid       NWS Marquette MI     Minor   Expected
# 413999         None        Avoid       NWS Wakefield VA     Minor   Expected
#
#                            web
# 0       http://www.weather.gov
# 1       http://www.weather.gov
# 2       http://www.weather.gov
# 3       http://www.weather.gov
# 4       http://www.weather.gov
# ...                        ...
# 413995  http://www.weather.gov
# 413996  http://www.weather.gov
# 413997  http://www.weather.gov
# 413998  http://www.weather.gov
# 413999  http://www.weather.gov
#
# [414000 rows x 80 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414000 entries, 0 to 413999
# Data columns (total 80 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   areaDesc                        378233 non-null  object
#  1   category                        413805 non-null  object
#  2   certainty                       413805 non-null  object
#  3   description                     413183 non-null  object
#  4   effective                       413007 non-null  object
#  5   event                           413805 non-null  object
#  6   eventCode_0_name                413805 non-null  object
#  7   eventCode_0_value               413805 non-null  object
#  8   eventCode_1_name                279535 non-null  object
#  9   eventCode_1_value               279535 non-null  object
#  10  expires                         413805 non-null  object
#  11  headline                        413530 non-null  object
#  12  instruction                     369840 non-null  object
#  13  onset                           409173 non-null  object
#  14  param_AWIPSidentifier           52867 non-null   object
#  15  param_AccountName               1 non-null       object
#  16  param_AccountPassword           1 non-null       object
#  17  param_AssignedAddress           657 non-null     object
#  18  param_AudioSource               657 non-null     object
#  19  param_BLOCKCHANNEL              335806 non-null  object
#  20  param_CMAMText                  1 non-null       object
#  21  param_CMAMlongtext              1749 non-null    object
#  22  param_CMAMtext                  8021 non-null    object
#  23  param_DA Page Address           1 non-null       object
#  24  param_DA Page Sequence Number   1 non-null       object
#  25  param_DBGFBYPASS                5 non-null       object
#  26  param_EAS                       16 non-null      object
#  27  param_EAS-ORG                   197611 non-null  object
#  28  param_EAS-STN-ID                355 non-null     object
#  29  param_EASAudioDuration          16 non-null      object
#  30  param_EASDescription            16 non-null      object
#  31  param_EASHeader                 657 non-null     object
#  32  param_EASText                   715 non-null     object
#  33  param_EMnet Nodes               85 non-null      object
#  34  param_Email                     1 non-null       object
#  35  param_Email To                  40 non-null      object
#  36  param_HazardType                6900 non-null    object
#  37  param_MessagePriority           657 non-null     object
#  38  param_NWSheadline               182505 non-null  object
#  39  param_Notification              16 non-null      object
#  40  param_OriginatingSystem         657 non-null     object
#  41  param_PIL                       317072 non-null  object
#  42  param_PostToWeb                 656 non-null     object
#  43  param_ReceiptsRequested         657 non-null     object
#  44  param_SMS                       1 non-null       object
#  45  param_ShortText                 552 non-null     object
#  46  param_SirenActivation           16 non-null      object
#  47  param_SirenDuration             657 non-null     object
#  48  param_StationID                 657 non-null     object
#  49  param_TimeZone                  60 non-null      object
#  50  param_Timezone                  1 non-null       object
#  51  param_USGSMsgType               5 non-null       object
#  52  param_UserAuthentication        1 non-null       object
#  53  param_UserName                  657 non-null     object
#  54  param_VTEC                      308442 non-null  object
#  55  param_VoiceRepeat               657 non-null     object
#  56  param_WEAHandling               2056 non-null    object
#  57  param_WMOidentifier             52867 non-null   object
#  58  param_eventEndingTime           285186 non-null  object
#  59  param_eventMotionDescription    52169 non-null   object
#  60  param_expiredReferences         37349 non-null   object
#  61  param_hailSize                  16253 non-null   object
#  62  param_hailThreat                4294 non-null    object
#  63  param_maxHailSize               10638 non-null   object
#  64  param_maxWindGust               9804 non-null    object
#  65  param_route                     16 non-null      object
#  66  param_thunderstormDamageThreat  708 non-null     object
#  67  param_timezone                  1823 non-null    object
#  68  param_tornadoDamageThreat       87 non-null      object
#  69  param_tornadoDetection          4749 non-null    object
#  70  param_waterspoutDetection       997 non-null     object
#  71  param_windGust                  13094 non-null   object
#  72  param_windThreat                4294 non-null    object
#  73  polygon_coordinates             162721 non-null  object
#  74  polygon_type                    162721 non-null  object
#  75  responseType                    413805 non-null  object
#  76  senderName                      413790 non-null  object
#  77  severity                        413805 non-null  object
#  78  urgency                         413805 non-null  object
#  79  web                             409207 non-null  object
# dtypes: object(80)
# memory usage: 252.7+ MB

# %% [markdown]
# #### Extracting Relevant Columns

# %%
important_comlumns = ['areaDesc', 'category', 'certainty', 'description', 'effective', 'event', 'headline', 'instruction', 'responseType', 'senderName', 'severity', 'urgency']
df = df[important_comlumns]
df
# Out:
#                                                  areaDesc category certainty  \
# 0                            Port Heiden to Cape Sarichef      Met  Observed
# 1                                           Kiska to Attu      Met    Likely
# 2       Carter, OK; Coal, OK; Garvin, OK; Johnston, OK...      Met  Observed
# 3       Green Bay south of line from  Cedar River to R...      Met    Likely
# 4       Coastal waters from Baffin Bay to Port Aransas...      Met    Likely
# ...                                                   ...      ...       ...
# 413995  Marion; Wahkiakum; Clackamas; Columbia; Washin...      Met    Likely
# 413996                                             Marion      Met  Possible
# 413997  Rich; Utah; Weber; Wasatch; Cache; Morgan; Jua...      Met    Likely
# 413998  Marquette to Munising MI; Huron Islands to Mar...      Met    Likely
# 413999  Chesapeake Bay from New Point Comfort to Littl...      Met    Likely
#
#                                               description  \
# 0       AAA\n\n.TONIGHT...SW wind 40 kt increasing to ...
# 1       AAA\n\n.TONIGHT...SW wind 20 kt becoming S 45 ...
# 2       The National Weather Service in Norman has iss...
# 3       Winds have subsided over the Bay of Green Bay ...
# 4       * WHAT...South winds 20 to 25 knots with gusts...
# ...                                                   ...
# 413995  THE NATIONAL WEATHER SERVICE IN PORTLAND HAS C...
# 413996  KSC115-252200-\n/O.CAN.KICT.SV.A.0520.000000T0...
# 413997  * AFFECTED AREA...THE WASATCH MOUNTAINS OF NOR...
# 413998  A SMALL CRAFT ADVISORY REMAINS IN EFFECT UNTIL...
# 413999  THE NATIONAL WEATHER SERVICE IN WAKEFIELD HAS ...
#
#                         effective                        event  \
# 0       2021-10-10T18:33:00-08:00                Storm Warning
# 1       2021-10-10T18:33:00-08:00                 Gale Warning
# 2       2021-10-10T20:59:00-05:00  Severe Thunderstorm Warning
# 3       2021-10-10T21:45:00-05:00         Small Craft Advisory
# 4       2021-10-10T21:56:00-05:00         Small Craft Advisory
# ...                           ...                          ...
# 413995  2016-12-17T14:37:34-08:00      Winter Weather Advisory
# 413996  2016-12-25T14:58:14-06:00    Severe Thunderstorm Watch
# 413997  2016-12-25T15:33:36-07:00         Winter Storm Warning
# 413998  2016-12-27T10:29:49-05:00         Small Craft Advisory
# 413999  2016-12-26T01:02:35-05:00         Small Craft Advisory
#
#                                                  headline  \
# 0       Storm Warning issued October 10 at 6:33PM AKDT...
# 1       Gale Warning issued October 10 at 6:33PM AKDT ...
# 2       Severe Thunderstorm Warning issued October 10 ...
# 3       Small Craft Advisory issued October 10 at 9:45...
# 4       Small Craft Advisory issued October 10 at 9:56...
# ...                                                   ...
# 413995  Winter Weather Advisory issued December 17 at ...
# 413996  Severe Thunderstorm Watch issued December 25 a...
# 413997  Winter Storm Warning issued December 25 at 3:3...
# 413998  Small Craft Advisory issued December 27 at 10:...
# 413999  Small Craft Advisory issued December 26 at 1:0...
#
#                                               instruction responseType  \
# 0                                                    None        Avoid
# 1                                                    None        Avoid
# 2       A Tornado Watch remains in effect for the warn...      Shelter
# 3                                                    None        Avoid
# 4       Inexperienced mariners, especially those opera...        Avoid
# ...                                                   ...          ...
# 413995                                               \n\n      Execute
# 413996                                               \n\n      Monitor
# 413997  A WINTER STORM WARNING FOR HEAVY SNOW MEANS TH...      Prepare
# 413998  A SMALL CRAFT ADVISORY MEANS THAT WIND SPEEDS ...        Avoid
# 413999  A SMALL CRAFT ADVISORY MEANS WIND SPEEDS OF 20...        Avoid
#
#                    senderName  severity    urgency
# 0            NWS Anchorage AK    Severe  Immediate
# 1            NWS Anchorage AK  Moderate   Expected
# 2               NWS Norman OK    Severe  Immediate
# 3            NWS Green Bay WI     Minor   Expected
# 4       NWS Corpus Christi TX     Minor   Expected
# ...                       ...       ...        ...
# 413995        NWS Portland OR  Moderate   Expected
# 413996         NWS Wichita KS    Severe     Future
# 413997  NWS Salt Lake City UT    Severe   Expected
# 413998       NWS Marquette MI     Minor   Expected
# 413999       NWS Wakefield VA     Minor   Expected
#
# [414000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414000 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      378233 non-null  object
#  1   category      413805 non-null  object
#  2   certainty     413805 non-null  object
#  3   description   413183 non-null  object
#  4   effective     413007 non-null  object
#  5   event         413805 non-null  object
#  6   headline      413530 non-null  object
#  7   instruction   369840 non-null  object
#  8   responseType  413805 non-null  object
#  9   senderName    413790 non-null  object
#  10  severity      413805 non-null  object
#  11  urgency       413805 non-null  object
# dtypes: object(12)
# memory usage: 37.9+ MB

# %%
df = df.dropna(subset=['category', 'areaDesc', 'senderName'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413805 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      378233 non-null  object
#  1   category      413805 non-null  object
#  2   certainty     413805 non-null  object
#  3   description   413183 non-null  object
#  4   effective     413007 non-null  object
#  5   event         413805 non-null  object
#  6   headline      413530 non-null  object
#  7   instruction   369840 non-null  object
#  8   responseType  413805 non-null  object
#  9   senderName    413790 non-null  object
#  10  severity      413805 non-null  object
#  11  urgency       413805 non-null  object
# dtypes: object(12)
# memory usage: 41.0+ MB

# %%
df = df.dropna(subset=['areaDesc'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 378233 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      378233 non-null  object
#  1   category      378233 non-null  object
#  2   certainty     378233 non-null  object
#  3   description   377813 non-null  object
#  4   effective     377700 non-null  object
#  5   event         378233 non-null  object
#  6   headline      378041 non-null  object
#  7   instruction   343739 non-null  object
#  8   responseType  378233 non-null  object
#  9   senderName    378218 non-null  object
#  10  severity      378233 non-null  object
#  11  urgency       378233 non-null  object
# dtypes: object(12)
# memory usage: 37.5+ MB

# %%
df = df.dropna(subset=['senderName'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 378218 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      378218 non-null  object
#  1   category      378218 non-null  object
#  2   certainty     378218 non-null  object
#  3   description   377801 non-null  object
#  4   effective     377696 non-null  object
#  5   event         378218 non-null  object
#  6   headline      378037 non-null  object
#  7   instruction   343737 non-null  object
#  8   responseType  378218 non-null  object
#  9   senderName    378218 non-null  object
#  10  severity      378218 non-null  object
#  11  urgency       378218 non-null  object
# dtypes: object(12)
# memory usage: 37.5+ MB

# %%
unique_counts = df.nunique()
print(unique_counts)
# Out:
# areaDesc         95212
# category            22
# certainty            5
# description     301009
# effective       257084
# event              206
# headline        281505
# instruction      38560
# responseType        13
# senderName         855
# severity             5
# urgency              5
# dtype: int64

# %%
df['category'].unique()
# Out:
# array(['Met', 'Other', 'Rescue', 'Safety', 'Security', 'Geo', 'Health',
#        'Infra', 'Env', 'Transport', 'Fire', 'Safety, Geo',
#        'Safety, Rescue', 'Met, Safety', 'Met, Health', 'Other, Safety',
#        'Met, Safety, Health', 'Safety, Health', 'Safety, Met',
#        'Safety, Security', 'Safety, Other', 'Health, Env'], dtype=object)

# %%
df['certainty'].unique()
# Out:
# array(['Observed', 'Likely', 'Possible', 'Unknown', 'Unlikely'],
#       dtype=object)

# %%
df['event'].unique()
# Out:
# array(['Storm Warning', 'Gale Warning', 'Severe Thunderstorm Warning',
#        'Small Craft Advisory', 'Tornado Watch',
#        'Special Weather Statement', 'Heavy Freezing Spray Warning',
#        'Flash Flood Warning', 'Flood Advisory', 'Tornado Warning',
#        'Special Marine Warning', 'Wind Advisory',
#        'Marine Weather Statement', 'Coastal Flood Advisory',
#        'Frost Advisory', 'Red Flag Warning', 'High Wind Warning',
#        'Beach Hazards Statement', 'Flood Warning', 'Coastal Flood Watch',
#        'Freeze Watch', 'Hard Freeze Warning', 'High Wind Watch',
#        'High Surf Advisory', 'Flood Watch', 'required monthly test',
#        'Flash Flood Watch', 'Coastal Flood Statement',
#        'Rip Current Statement', 'Coastal Flood Warning',
#        'Child Abduction Emergency', 'Hard Freeze Watch',
#        'Winter Storm Watch', 'Freeze Warning', 'Lake Wind Advisory',
#        'Winter Storm Warning', 'Winter Weather Advisory',
#        'Hazardous Seas Warning', 'Fire Weather Watch',
#        'required weekly test', 'Dense Fog Advisory',
#        'Local Area Emergency', 'Civil Emergency Message',
#        'Required Weekly Test', 'Blowing Dust Advisory',
#        'Practice/Demo Warning', 'Blowing Dust Warning',
#        'Required Monthly Test', 'REQUIRED WEEKLY TEST', 'RWT',
#        'The Police Unity Tour will be visiting D', 'Dust Advisory',
#        'practice/demo message', 'Law Enforcement Blue Alert',
#        'Gale Watch', 'MISSING 16 YEAR OLD', 'Law Enforcement Warning',
#        'Low Water Advisory', 'Severe Thunderstorm Watch',
#        'Administrative Message', 'Routine Weekly Test',
#        'Water Main Break in Denton', 'IPAWS Amber Alert Template',
#        'Hydrologic Outlook', 'Lakeshore Flood Advisory', 'Storm Watch',
#        'High Surf Warning', 'Planned Event', 'REQUIRED MONTHLY TEST',
#        'Brisk Wind Advisory', 'Blizzard Warning', 'Wind Chill Advisory',
#        'Freezing Fog Advisory', 'BLUE Alert', 'Shelter in Place Warning',
#        'Hazardous Seas Watch', 'Air Stagnation Advisory',
#        'Wind Chill Warning', 'Local Area Emergency Warning',
#        'Silver Alert Raul Hernandez Dyer IN', 'Heat Advisory',
#        'SPD/SFD-Safety-911 Outage', 'Excessive Heat Warning',
#        'Lakeshore Flood Watch', 'Dense Smoke Advisory',
#        'Lakeshore Flood Warning', 'Snow Squall Warning',
#        'Dust Storm Warning', 'Civil Danger Warning', 'Wind Chill Watch',
#        'Hurricane Force Wind Warning', 'Heavy Freezing Spray Advisory',
#        'Avalanche Advisory', 'Lake Effect Snow Warning',
#        'CHILD ABDUCTION EMERGENCY', 'civil emergency message',
#        'Porter County Emergency Alert Test',
#        'TEST-Required Weekly Test-TEST', 'Ice Storm Warning',
#        'TEST - Required Weekly Test - TEST', 'Evacuation Immediate',
#        'Boil Order', 'Fire Warning', 'Excessive Heat Watch',
#        'Pipeline Flooding-COF #2',
#        '*CCEM - Museum - Threshold #2 - Flooding', 'CEM',
#        'Pipeline Flood-COF#3', 'PRACTICE/DEMO WARNING',
#        'City of Ithaca natural gas disruption', 'Flash Flood Statement',
#        'Severe Weather Statement', 'Flood Statement', 'Hurricane Warning',
#        'Hurricane Watch', 'Storm Surge Watch', 'Tropical Storm Watch',
#        'Tropical Storm Warning', 'Storm Surge Warning',
#        'Tropical Cyclone Statement', 'Blizzard Watch',
#        'Extreme Fire Danger', 'Monthly EAS Test - CCEMA',
#        'Administrative Message/Follow up Statement',
#        'Freezing Rain Advisory', 'Lake Effect Snow Advisory',
#        'Small Craft Advisory for Winds',
#        'Small Craft Advisory for Hazardous Seas',
#        'Small Craft Advisory for Rough Bar', 'Lake Effect Snow Watch',
#        'Heavy Freezing Spray Watch', 'ADMINISTRATIVE MESSAGE',
#        'Boil Water Order', 'Test Message IPAWS OPEN CAP EAS Feed',
#        '911 TELEPHONE OUTAGE EMERGENCY', '9-1-1 Call',
#        'Practice Demo Test', 'Typhoon Warning', 'test', 'Missing child',
#        'Avalanche Warning', 'COVID-19 Response', 'TEST TEST TEST',
#        'Communications', 'TEST -Required Weekly Test -TEST',
#        'child abduction emergency', 'Earthquake Warning',
#        'Hazardous Materials Warning', '911 Telephone Outage Emergency',
#        'Hurricane Force Wind Watch', 'NATIONAL PERIODIC TEST',
#        'Shelter In Place Warning', 'Lakeshore Flood Statement',
#        'Typhoon Watch', '9-1-1 telephone outage emergency', 'Test',
#        'IPAWS weekly test', 'THIS IS A TEST', 'Ashfall Advisory',
#        'Extreme Wind Warning', 'Tsunami Warning',
#        'Whittier WEA Test- Haz Mat Spill', 'Required Monthly EAS Test',
#        'Flood Watch (Areal)', 'Flood Warning (Areal)',
#        'Flood Warning (for Forecast Points)',
#        'Extreme Cold Warning (Alaska only)', 'IPAWS Weekly Test',
#        '911 Outage/Power Outage', '911 System Back Up & Running',
#        'Tsunami Watch', 'Tsunami Advisory', 'Severe Weather Warning',
#        'Environmental Hazard Warning', 'Blue Alert', 'TN BLUE ALERT',
#        'TEST IPAWS WEA Alert TEST', 'Monthly Test',
#        'Infrastructure - Not Otherwise Categorized',
#        'Celluar 9-1-1 Disruptions ', 'Celluar 9-1-1 Disruptions', 'AMBER',
#        'Hazardous materials Warning', 'Routine Monthly Test',
#        'WEA TEST 10:15 a.m.', 'Flooded roads in Weakley County',
#        '30 Dec Active Test Message 2',
#        'Other - Not Otherwise Categorized',
#        'City of Camden Boil Water Alert', 'EUP EMERGENCY ALERT TEST ONLY',
#        'TEST ONLY TO MONTEREY (fm Marin production system)',
#        'NATIONAL EMERGENCY ACTION NOTIFICATION',
#        'I64 Closed at 148 Eastbound', 'Suspect Wanted',
#        'AMBER ALERT - MISSOURI', 'CANCELED AMBER ALERT - MISSOURI',
#        'Gas Leak Shelter-in-Place', 'TES - Required Weekly Test  - TEST',
#        'Shelter in place 9/15/19', 'CAE ',
#        'Avon Water Main Break - Conserve Water', 'Gas Leak',
#        'Evacuation Immediate Warning', 'Gas Leak All Clear',
#        'RUNAWAY JUVENILE - SAMANTHA MARIE CRAIG', 'test test test tooele'],
#       dtype=object)

# %% [markdown]
# Removing Test Alerts which are irrelevant for our use-case

# %%
# Drop rows where 'event' column contains the word 'test' (case-insensitive)
filtered_df = df[~df['event'].str.contains('test', case=False, na=False)]

# Display the updated dataframe
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 375714 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      375714 non-null  object
#  1   category      375714 non-null  object
#  2   certainty     375714 non-null  object
#  3   description   375324 non-null  object
#  4   effective     375444 non-null  object
#  5   event         375714 non-null  object
#  6   headline      375552 non-null  object
#  7   instruction   342784 non-null  object
#  8   responseType  375714 non-null  object
#  9   senderName    375714 non-null  object
#  10  severity      375714 non-null  object
#  11  urgency       375714 non-null  object
# dtypes: object(12)
# memory usage: 37.3+ MB

# %%
unique_counts = filtered_df.nunique()
print(unique_counts)
# Out:
# areaDesc         94988
# category            21
# certainty            5
# description     300473
# effective       254945
# event              174
# headline        281314
# instruction      38432
# responseType        13
# senderName         595
# severity             5
# urgency              5
# dtype: int64

# %%
filtered_df['responseType'].unique()
# Out:
# array(['Avoid', 'Shelter', 'AllClear', 'Execute', 'Monitor', 'Prepare',
#        '', 'None', 'Evacuate', 'Prepare, Monitor', 'Assess',
#        'Prepare, Monitor, Avoid', 'Prepare, Avoid'], dtype=object)

# %%
filtered_df['severity'].unique()
# Out:
# array(['Severe', 'Moderate', 'Minor', 'Extreme', 'Unknown'], dtype=object)

# %%
filtered_df['urgency'].unique()
# Out:
# array(['Immediate', 'Expected', 'Past', 'Future', 'Unknown'], dtype=object)

# %%
filtered_df['description'].head(10)
# Out:
# 0    AAA\n\n.TONIGHT...SW wind 40 kt increasing to ...
# 1    AAA\n\n.TONIGHT...SW wind 20 kt becoming S 45 ...
# 2    The National Weather Service in Norman has iss...
# 3    Winds have subsided over the Bay of Green Bay ...
# 4    * WHAT...South winds 20 to 25 knots with gusts...
# 5    The Tornado Watch has been cancelled and is no...
# 6    AAA\n\n.TONIGHT...N wind 35 kt. Seas 12 ft. Ra...
# 7    The Severe Thunderstorm Warning has been cance...
# 8    The Severe Thunderstorm Warning has been cance...
# 9    * WHAT...South winds 15 to 20 kts with gusts t...
# Name: description, dtype: object

# %%
filtered_df['description'] = filtered_df['description'].str.replace(r'\*|\n+|\.{3}', ' ', regex=True)
filtered_df['description'][0]
# Out:
# <ipython-input-30-49806dda0596>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['description'] = filtered_df['description'].str.replace(r'\*|\n+|\.{3}', ' ', regex=True)
# 'AAA .TONIGHT SW wind 40 kt increasing to 50 kt after midnight. From Port Moller E, SW wind 35 kt increasing to 45 kt after midnight. Seas 22 ft. .MON W wind 40 kt. Seas 21 ft. Rain showers. .MON NIGHT W wind 35 kt. Seas 18 ft subsiding to 12 ft after midnight. .TUE AND TUE NIGHT W wind 30 kt. Seas 12 ft. .WED THROUGH FRI W wind 30 kt. Seas 14 ft. '

# %%
filtered_df['description'] = (
    filtered_df['description']
    .str.strip()                       # Remove leading and trailing spaces
    .str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces with a single space
)
filtered_df['description'][0]
# Out:
# <ipython-input-31-c7b3b857ed78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['description'] = (
# 'AAA .TONIGHT SW wind 40 kt increasing to 50 kt after midnight. From Port Moller E, SW wind 35 kt increasing to 45 kt after midnight. Seas 22 ft. .MON W wind 40 kt. Seas 21 ft. Rain showers. .MON NIGHT W wind 35 kt. Seas 18 ft subsiding to 12 ft after midnight. .TUE AND TUE NIGHT W wind 30 kt. Seas 12 ft. .WED THROUGH FRI W wind 30 kt. Seas 14 ft.'

# %%
filtered_df['instruction'] = filtered_df['instruction'].str.replace(r'\n', ' ', regex=True)
filtered_df['instruction'][0]
# Out:
# <ipython-input-32-3ebddc3076b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['instruction'] = filtered_df['instruction'].str.replace(r'\n', ' ', regex=True)

# %%
filtered_df['headline'] = filtered_df['headline'].str.replace(r'\*|\n+|\.{3}', ' ', regex=True)
# Out:
# <ipython-input-33-8809f106158e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['headline'] = filtered_df['headline'].str.replace(r'\*|\n+|\.{3}', ' ', regex=True)

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 375714 entries, 0 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      375714 non-null  object
#  1   category      375714 non-null  object
#  2   certainty     375714 non-null  object
#  3   description   375324 non-null  object
#  4   effective     375444 non-null  object
#  5   event         375714 non-null  object
#  6   headline      375552 non-null  object
#  7   instruction   342784 non-null  object
#  8   responseType  375714 non-null  object
#  9   senderName    375714 non-null  object
#  10  severity      375714 non-null  object
#  11  urgency       375714 non-null  object
# dtypes: object(12)
# memory usage: 45.3+ MB

# %%
filtered_df = filtered_df.dropna(subset=['description', 'headline', 'instruction'])
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342758 entries, 2 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      342758 non-null  object
#  1   category      342758 non-null  object
#  2   certainty     342758 non-null  object
#  3   description   342758 non-null  object
#  4   effective     342681 non-null  object
#  5   event         342758 non-null  object
#  6   headline      342758 non-null  object
#  7   instruction   342758 non-null  object
#  8   responseType  342758 non-null  object
#  9   senderName    342758 non-null  object
#  10  severity      342758 non-null  object
#  11  urgency       342758 non-null  object
# dtypes: object(12)
# memory usage: 34.0+ MB

# %%
filtered_df.nunique()
# Out:
# areaDesc         88645
# category            21
# certainty            5
# description     276872
# effective       239157
# event              149
# headline        263848
# instruction      37337
# responseType        13
# senderName         336
# severity             5
# urgency              5
# dtype: int64

# %%
# Check for duplicate rows in the entire DataFrame
duplicates = filtered_df.duplicated(keep=False)

# Display rows that are duplicates (if any)
duplicate_rows = filtered_df[duplicates]

print("Are there any duplicate rows in the dataset?")
print(duplicates.any())  # True if there are duplicate rows, False otherwise

if duplicates.any():
    print("\nDuplicate rows:")
    print(duplicate_rows)
# Out:
# Are there any duplicate rows in the dataset?
# True
#
# Duplicate rows:
#                                                  areaDesc category certainty  \
# 3448    Southern Brevard County; Indian River; St. Luc...      Met    Likely
# 3471    Southern Brevard County; Indian River; St. Luc...      Met    Likely
# 6398                                        Affected Area    Other  Unlikely
# 7279         Juneau Borough and Northern Admiralty Island      Met    Likely
# 7280    Grand Traverse Bay south of a line Grand Trave...      Met    Likely
# ...                                                   ...      ...       ...
# 412189                                            Jackson      Met  Observed
# 412190      Dyer; Lake; Pemiscot; Mississippi; Lauderdale      Met  Observed
# 412191                       Wheeler; Telfair; Montgomery      Met  Observed
# 412192             Knox; Whitley; Clay; Bell; Owsley; Lee      Met  Possible
# 412193  Emmet; Calhoun; Humboldt; Franklin; Pocahontas...      Met    Likely
#
#                                               description  \
# 3448    WHAT East winds up to around 15mph will produc...
# 3471    WHAT East winds up to around 15mph will produc...
# 6398    This is a test of the Emergency Alert System f...
# 7279    WHAT Snow and blowing snow expected. Total sno...
# 7280    WHAT Highest gusts up to 30 kt from the southw...
# ...                                                   ...
# 412189  The Flood Warning continues for the following ...
# 412190  The Flood Advisory continues for the Mississip...
# 412191  Ocmulgee River near Dames Ferry affecting Jone...
# 412192  WINTER STORM WATCH IN EFFECT FROM THURSDAY EVE...
# 412193  WIND CHILLS HAVE CONTINUED TO IMPROVE EARLY TH...
#
#                         effective                    event  \
# 3448    2021-10-19T03:20:00-04:00  Beach Hazards Statement
# 3471    2021-10-19T03:20:00-04:00  Beach Hazards Statement
# 6398                         None            Planned Event
# 7279    2021-11-11T15:32:00-09:00  Winter Weather Advisory
# 7280    2021-11-11T19:06:00-05:00     Small Craft Advisory
# ...                           ...                      ...
# 412189  2016-01-02T09:39:16-05:00          Flood Statement
# 412190  2016-01-19T20:08:55-06:00           Flood Advisory
# 412191  2016-01-01T13:56:51-05:00          Flood Statement
# 412192  2016-01-20T05:05:10-05:00       Winter Storm Watch
# 412193  2016-01-18T08:58:14-06:00       Wind Chill Warning
#
#                                                  headline  \
# 3448    Beach Hazards Statement issued October 19 at 3...
# 3471    Beach Hazards Statement issued October 19 at 3...
# 6398                                 Required Weekly Test
# 7279    Winter Weather Advisory issued November 11 at ...
# 7280    Small Craft Advisory issued November 11 at 7:0...
# ...                                                   ...
# 412189  Flood Statement issued January 2 at 9:39AM EST...
# 412190  Flood Advisory issued January 19 at 8:08PM CST...
# 412191  Flood Statement issued January 1 at 1:56PM EST...
# 412192  Winter Storm Watch issued January 20 at 5:04AM...
# 412193  Wind Chill Warning issued January 18 at 8:58AM...
#
#                                               instruction responseType  \
# 3448    Swim near a lifeguard. If caught in a rip curr...        Avoid
# 3471    Swim near a lifeguard. If caught in a rip curr...        Avoid
# 6398    This test was conducted using the Rochester Al...         None
# 7279    Slow down and use caution while traveling.  Fo...      Execute
# 7280    Inexperienced mariners, especially those opera...        Avoid
# ...                                                   ...          ...
# 412189  FLC063-031439- /O.CON.KTAE.FL.W.0051.000000T00...        Avoid
# 412190  ARC093-MOC155-TNC045-095-097-210208- /O.CON.KM...        Avoid
# 412191                                                           Avoid
# 412192  A WINTER STORM WATCH MEANS THERE IS A POTENTIA...      Prepare
# 412193                                                         Prepare
#
#                    senderName  severity    urgency
# 3448         NWS Melbourne FL  Moderate   Expected
# 3471         NWS Melbourne FL  Moderate   Expected
# 6398          Rochester-Alert     Minor       Past
# 7279            NWS Juneau AK  Moderate   Expected
# 7280           NWS Gaylord MI     Minor   Expected
# ...                       ...       ...        ...
# 412189     NWS Tallahassee FL    Severe  Immediate
# 412190         NWS Memphis TN     Minor   Expected
# 412191  NWS Peachtree City GA    Severe  Immediate
# 412192         NWS Jackson KY    Severe     Future
# 412193      NWS Des Moines IA    Severe   Expected
#
# [32419 rows x 12 columns]

# %%
filtered_df = filtered_df.drop_duplicates(keep='first')
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 325901 entries, 2 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      325901 non-null  object
#  1   category      325901 non-null  object
#  2   certainty     325901 non-null  object
#  3   description   325901 non-null  object
#  4   effective     325847 non-null  object
#  5   event         325901 non-null  object
#  6   headline      325901 non-null  object
#  7   instruction   325901 non-null  object
#  8   responseType  325901 non-null  object
#  9   senderName    325901 non-null  object
#  10  severity      325901 non-null  object
#  11  urgency       325901 non-null  object
# dtypes: object(12)
# memory usage: 32.3+ MB

# %%
filtered_df['effective'] = pd.to_datetime(filtered_df['effective'], utc=True)
print(filtered_df['effective'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-cddc54bbec8f> in <cell line: 2>()
#       1 filtered_df['effective'] = pd.to_datetime(filtered_df['effective'], utc=True)
# ----> 2 print(filtered_df['effective'][0])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 325901 entries, 2 to 413999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   areaDesc      325901 non-null  object
#  1   category      325901 non-null  object
#  2   certainty     325901 non-null  object
#  3   description   325901 non-null  object
#  4   effective     325847 non-null  datetime64[ns, UTC]
#  5   event         325901 non-null  object
#  6   headline      325901 non-null  object
#  7   instruction   325901 non-null  object
#  8   responseType  325901 non-null  object
#  9   senderName    325901 non-null  object
#  10  severity      325901 non-null  object
#  11  urgency       325901 non-null  object
# dtypes: datetime64[ns, UTC](1), object(11)
# memory usage: 40.4+ MB

# %%
filtered_df.to_csv('IPAWS_Filtered_Data.csv', index=False)
